# %%
# %pip install -q google_play_scraper 
# %pip install -q transformers 
# %pip install -q plotly-express 
# %pip install pyyaml
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pyyaml in c:\users\ankus\appdata\local\programs\python\python312\lib\site-packages (6.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from google_play_scraper import app, Sort, reviews_all
import plotly.express as px

# %%
skill_cat_app = reviews_all("com.skillcat", sleep_milliseconds=0, lang='en', country='us', sort=Sort.NEWEST)

# %%
skill_cat_app
# Out:
# [{'reviewId': 'd0379e6a-cb80-4e70-91ba-fe25952f82fb',
#   'userName': 'Andrew Coffey',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVpZa_ZQEpOK4093_qttxUKc0KXFwBUNNYbVn0DWBvGeeDBmjPi',
#   'content': 'not free',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2024, 11, 9, 4, 7, 53),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '116d668e-b0c9-4c01-8196-8eaabe29b906',
#   'userName': 'Salami Saheed',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJXWC-qusi43VGkt56izWW2PtUSefxhddu3WI_fXBdHXlVCYA=mo',
#   'content': "I can't imagine how much I have learned about electricity and I to be an Electrician from this magnificent app. The app didn't leave any stone unturned. it treated every module in details. please just work on the frequent rebooting on the app update.",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 11, 7, 19, 6),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '5.3.4'},
#  {'reviewId': '8a2028f3-916c-47bf-a568-267210cae2aa',
#   'userName': 'Bill Fitzgerald',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKl2c-MI6BMEf5zAKZ_UUjJMMaDtOjPjWSNoynYSoGk16cU=mo',
#   'content': 'awesome app! got 608 cert and other training on it! thank you!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.0.1',
#   'at': datetime.datetime(2024, 11, 7, 8, 59, 23),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '6.0.1'},
#  {'reviewId': '7f0a3992-49cd-4a40-8345-4259d9ecaf29',
#   'userName': 'dj Ovamarz',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW6P490kfqj2aBawCzkc5u-WZjL4tt7ls6IAv_UMbaF6B3_Cs8',
#   'content': 'uhhh',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.0.1',
#   'at': datetime.datetime(2024, 11, 7, 0, 48, 55),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '6.0.1'},
#  {'reviewId': '1accd0cc-6efe-49d9-bfdc-a18eea12b3b6',
#   'userName': 'Nicolas Bowman',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocK87Olj4syFgjmCeFzj_2EsG258sXObD6HrtkLQVR9GAENoBw=mo',
#   'content': 'Now that the update is allowing me to get on school closer to when I need this done. The app is letting me get to every program with out a 30 minute to 1 hour wait time.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.0.1',
#   'at': datetime.datetime(2024, 11, 6, 4, 50, 27),
#   'replyContent': 'Thanks for your review and we appreciate you taking the time. We had a brief intermission while our team was updating our servers, but everything is back up and running now. Please try to hop into the app when you get a chance. If you run into any issues, you can always reach out to us at info@skillcatapp.com for assistance!',
#   'repliedAt': datetime.datetime(2024, 11, 6, 2, 48),
#   'appVersion': '6.0.1'},
#  {'reviewId': 'd3607d5f-3578-4117-8e5a-e36f2cda82e0',
#   'userName': 'Joseph Seymour',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKN6QlWIBv56AKT28qGVGrfom0GkkAX9yerQsBPu2XOq6RlYA=mo',
#   'content': 'great program for refreshing yourself on your carpentry trade knowledge or familiarizing yourself with a new trade.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.0.1',
#   'at': datetime.datetime(2024, 11, 6, 3, 27, 58),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '6.0.1'},
#  {'reviewId': '9a315b9e-6f08-43c4-adde-ed6bd63f77e1',
#   'userName': 'Divine Mapfinya',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIesRBFeeZ3v4hBYNH_YFzA4TaxzbUFHNzUX4qsyEJkyaf9Gg=mo',
#   'content': "It's great",
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.0.1',
#   'at': datetime.datetime(2024, 11, 5, 11, 33, 36),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '6.0.1'},
#  {'reviewId': '01be3b11-e040-4e66-8381-335e77050129',
#   'userName': 'Imassive Crew',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUHjPVrb4o-9zhwlXFBTFBoIDvsMxoNiR6eiC6fycm4qMkXRCQ',
#   'content': 'Very powerful',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2024, 11, 4, 7, 9, 43),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '19c335b6-ef75-474b-a9a7-859b5e37d36a',
#   'userName': 'Jy L',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocK_CDoKJHWW9B-HDfLwre2pGShQq2r9WBe_jwoULcI0M6okHA=mo',
#   'content': 'Went through the 3-day trial. The information was great. My 3-day trial expired so I bought the monthly subscription and now the app will not open. If I uninstall the app and reinstall it will I still be able to get the monthly subscription?',
#   'score': 2,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '6.0.1',
#   'at': datetime.datetime(2024, 11, 2, 2, 23, 43),
#   'replyContent': "Hey there, subscriptions are tied to your account, so you won't lose it just by uninstalling and reinstalling. Please reach out to us at info@skillcatapp.com so we can dive into your issue and get it fixed ASAP!",
#   'repliedAt': datetime.datetime(2024, 11, 6, 2, 48, 53),
#   'appVersion': '6.0.1'},
#  {'reviewId': '2915151a-f2d3-4d31-a6e8-c1092fd0ad87',
#   'userName': 'Clint Gazzaway',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJMAmJPpKkltAty_2LHlCqpMRnfdYMZ8Ug7G4lcVeMTfIt4MQ=mo',
#   'content': 'Easy to understand courses, that you can do at your own speed.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.0.1',
#   'at': datetime.datetime(2024, 10, 31, 8, 32, 8),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '6.0.1'},
#  {'reviewId': 'fd94f55d-1d80-4c67-b2d1-7e0bb5503156',
#   'userName': 'saleem khan',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXvK6L6Akj1jXlT8hpJjk41O1GKY5Hg0_WMW3F9Ntm_RAFb868jhw',
#   'content': 'nice skillcat apps',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.0.1',
#   'at': datetime.datetime(2024, 10, 30, 19, 18),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '6.0.1'},
#  {'reviewId': '516a2402-cdb6-4059-a1de-03cf2e959a67',
#   'userName': 'Shahram Nabizada',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWBafA3y81eI9PL3A-3RfsMLk6DglDH62ZyKQL3TUo5d2h50Ns',
#   'content': 'Waste, not what they say.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2024, 10, 30, 7, 3, 8),
#   'replyContent': "Hi Shahram, I'm sorry you feel this way. What exactly were you looking for that you didn't find? We would like to do whatever we can to improve the SkillCat experience for you. Feel free to reach out to us at info@skillcatapp.com so we can help!",
#   'repliedAt': datetime.datetime(2024, 11, 1, 2, 15, 1),
#   'appVersion': None},
#  {'reviewId': 'f72b8a9a-f23a-4f30-a993-6bb473c316ff',
#   'userName': 'Prince Komene Newton',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUvfsdJvYXuwOjq_iCTUz3dGnyaCGh_ldTbKQ-5RtIKNYddJlTA',
#   'content': 'Thank you very much. This was an excellent opportunity extended to me, and I can bet that this training has enhanced my electrical skills. It was an eye-opener for me.',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.0.1',
#   'at': datetime.datetime(2024, 10, 29, 18, 56, 7),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '6.0.1'},
#  {'reviewId': '90a0a70b-c09d-4a32-a328-714ec60b9206',
#   'userName': 'neal neal',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIRbDfBk8NrJiuMhCxI3QKbs-UE7ACIwMXaqB2OomvyCFwZ2A=mo',
#   'content': 'Ok',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.0.1',
#   'at': datetime.datetime(2024, 10, 28, 2, 24, 58),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '6.0.1'},
#  {'reviewId': '6326904b-9e01-4c27-81a4-c539d85eba86',
#   'userName': 'Arowosafe Kayode',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU8oeBAEEUFT50FdNh6VX9PbBQkz9WhtddFITtmRPFFho3QfDdu',
#   'content': 'Awesome, encouraging, and interesting with stress free to achieve.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.0.1',
#   'at': datetime.datetime(2024, 10, 27, 10, 54, 9),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '6.0.1'},
#  {'reviewId': '2deecc11-ed4b-4e75-ac10-313141f91318',
#   'userName': 'Afrika Peter',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU_cfGce5nVyeHsz0ZOav78zTS-n6CdQBGJOqWpSw5GH5sZ1-w',
#   'content': 'Good educational app to international standard🤗',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.0.1',
#   'at': datetime.datetime(2024, 10, 26, 20, 14, 50),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '6.0.1'},
#  {'reviewId': 'eb27dd5b-e5eb-48dd-94ff-282d506864e3',
#   'userName': 'Charles Morse',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKJe_f4a9qHfXcvvcTG2NRTSEYhkfK0tYBx6SjG-xz4-ig2_A=mo',
#   'content': "I couldn't sign in initially, but customer service got it figured out. Thanks!",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.0.1',
#   'at': datetime.datetime(2024, 10, 25, 23, 19, 13),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '6.0.1'},
#  {'reviewId': '83eb59f0-7e7d-43e8-8a8d-ca3c033efd4f',
#   'userName': 'Rig-on, Edgar O.',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVRjCpu5kne5NY40spe3Ci9iS03Prgk977EGJK_DQBA_etyQHFJ',
#   'content': 'I gain more knowledge with this apps',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2024, 10, 23, 9, 27, 21),
#   'replyContent': "Thank you so much for your positive feedback! We're thrilled to hear that the app has helped you gain more knowledge. Your success is our priority, and we’re glad to be a part of your learning journey!\n\nFeel free to reach out if you have any suggestions or need assistance.",
#   'repliedAt': datetime.datetime(2024, 10, 24, 17, 46, 5),
#   'appVersion': None},
#  {'reviewId': 'cc35cf23-6311-4cd8-ac01-9d6bd3d457c3',
#   'userName': 'Darlington Mike',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUSUPIglAHR36jtxTpJgaJ2ghile-lUSySeibjNx5Ut5kz3560',
#   'content': 'superp',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.0.1',
#   'at': datetime.datetime(2024, 10, 22, 1, 56, 11),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '6.0.1'},
#  {'reviewId': 'b08fedd0-3eac-40dd-9b2b-e036682296da',
#   'userName': 'Hams Wera',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJvVXvasj2cLNNQkeGUtuXYciEPES6rZ0KPnhfQouJHngfpbQ=mo',
#   'content': 'I try to sign in but it still give me an error. how please help me',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.0.1',
#   'at': datetime.datetime(2024, 10, 22, 1, 37, 6),
#   'replyContent': 'I\'m sorry to hear that you\'re having trouble signing in. Let\'s get this resolved for you!\n\nPlease make sure you\'re using the correct email and password. If you’re still seeing an error, you can try resetting your password using the "Forgot Password" option.\n\nIf the issue persists, please reach out to us at info@skillcatapp.com.',
#   'repliedAt': datetime.datetime(2024, 10, 24, 17, 47, 12),
#   'appVersion': '6.0.1'},
#  {'reviewId': '2ef70960-a310-4bda-957f-ccc7ee7f390d',
#   'userName': 'Joseph Day',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLHMm8TmlrFfUkEtVFL9CBgppfIMVNHIG6HGwSgjiTp69gWFw=mo',
#   'content': 'a lot of good information....',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.0.1',
#   'at': datetime.datetime(2024, 10, 21, 5, 42, 44),
#   'replyContent': "Thank you for your feedback! We're glad to hear that you found the information helpful. Our goal is to provide valuable content, and it's great to know it's making a positive impact.\n\nIf you have any suggestions or questions, feel free to reach out!",
#   'repliedAt': datetime.datetime(2024, 10, 24, 17, 47, 45),
#   'appVersion': '6.0.1'},
#  {'reviewId': '37c85dd7-9263-421a-9889-6258c0e416c2',
#   'userName': 'Khurshid Khan',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVfT5pZILfSh67vcw-5xpx0brgmwqFyq5L9PZPwYPXvIQq4IlY',
#   'content': 'SkillCat is a very diplomatic and 100% free learning platform with appreciable/helping cooperative staff I recommend to all technicians must be registered with SkillCat.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2024, 10, 19, 7, 40, 25),
#   'replyContent': 'Thank you so much for your wonderful review! We’re thrilled to hear that you had a positive experience with SkillCat and found our platform and staff helpful. Your recommendation means a lot to us, and we’re excited to continue supporting technicians in their learning journey.\n\n',
#   'repliedAt': datetime.datetime(2024, 10, 24, 17, 49, 13),
#   'appVersion': None},
#  {'reviewId': 'e5ce6832-b71e-47d9-903b-91aebfb55e0a',
#   'userName': 'Teddy Wales',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJHvhWlq432HgW3vMfiD2vHj3Bn6rJ41oGMDR0cIwJOXF4lww=mo',
#   'content': 'Great app. Enjoyed using it.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.0.1',
#   'at': datetime.datetime(2024, 10, 17, 22, 40, 38),
#   'replyContent': "Thank you for the great feedback! We're glad to hear that you enjoyed using the app. If you have any suggestions or need assistance, feel free to reach out. We're always here to help!",
#   'repliedAt': datetime.datetime(2024, 10, 24, 17, 49, 42),
#   'appVersion': '6.0.1'},
#  {'reviewId': '00b052a5-03d3-4f39-b544-4bda5a3081c8',
#   'userName': 'Bickal Mangrati',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVCN6rVPrgRktBJpemjVqu_1samtaAE-kYs-1pydhM6R9ToOc90',
#   'content': 'Best',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 10, 16, 17, 20, 20),
#   'replyContent': 'Thank you for your feedback! We’re glad you had a positive experience. If you have any thoughts to share or need assistance, feel free to let us know!',
#   'repliedAt': datetime.datetime(2024, 10, 24, 17, 50, 1),
#   'appVersion': '5.3.4'},
#  {'reviewId': 'a060f28b-f4b8-4783-abbd-3183ae1f29b8',
#   'userName': 'Bruce Nkambule',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUF4AU5Aqbzor4gH_Vp4XNflUHHMvsxCnMHYYO7CR-WMXoJp_fQ',
#   'content': 'Good app',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.0.1',
#   'at': datetime.datetime(2024, 10, 15, 23, 18, 30),
#   'replyContent': "Thank you for your positive feedback! We're glad to hear you think it's a good app. If you have any suggestions or questions, feel free to reach out!",
#   'repliedAt': datetime.datetime(2024, 10, 24, 17, 50, 26),
#   'appVersion': '6.0.1'},
#  {'reviewId': '79554e5b-7cbc-4e03-b9c7-67bdfb195304',
#   'userName': 'Skud Missal',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU13LMJcABoBDbBd49hdLBYl7ER5g5mTQVJkmyGQNNelv5am2w',
#   'content': 'All EPA certifications. Tons of certificates. Residential/ Commercial HVAC, Plumbing, Electrical, and Appliance Repair trade school diplomas available. 5* if all the errors were fixed, the voice over was better quality, and if they could replace, or limit, the 1000+ uses of the word "RECALL". Pros: Work at YOUR pace. Great value. Highly responsive customer service. Cons: Mostly monotone voice. A lot of bugs and information errors that are still being worked out (but they are being fixed).',
#   'score': 4,
#   'thumbsUpCount': 7,
#   'reviewCreatedVersion': '6.0',
#   'at': datetime.datetime(2024, 10, 15, 17, 41, 1),
#   'replyContent': "We take content issues very seriously and continuously work on updates to improve the accuracy and organization of our material. The tricky questions reflect the real EPA exam's complexity, helping users prepare better, which contributes to our 97% pass rate. We appreciate your input and will consider it as we make further improvements.",
#   'repliedAt': datetime.datetime(2024, 8, 23, 20, 0, 19),
#   'appVersion': '6.0'},
#  {'reviewId': '4f75f833-b7a3-454a-b376-2662f988d232',
#   'userName': 'vijay venkatesan',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXNu9XO_BntHiw7mvqdYXzgTZgZf4fgT1IGYx3JrG0WO0qtMFSsBw',
#   'content': 'Nice app',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.0',
#   'at': datetime.datetime(2024, 10, 15, 12, 45, 42),
#   'replyContent': 'Thank you for your kind words! We’re happy to hear you think it’s a nice app. If you have any feedback or questions, don’t hesitate to reach out!\n\n',
#   'repliedAt': datetime.datetime(2024, 10, 24, 17, 50, 49),
#   'appVersion': '6.0'},
#  {'reviewId': '1b30d925-0f5c-484e-978c-c9890f44e1ef',
#   'userName': 'Richard Richter II',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL1HAUC7OrKLyrs-XSfmsl6zyonmDuh955LuKrIFafmhLn18Q=mo',
#   'content': 'Great platform for learning new trades. Subscription was a no brainer after the free trial! Only downside thus far, has been losing the streaks once the app updated to the latest version.',
#   'score': 5,
#   'thumbsUpCount': 4,
#   'reviewCreatedVersion': '6.0',
#   'at': datetime.datetime(2024, 10, 15, 5, 14, 56),
#   'replyContent': "Thank you for your fantastic review! We're thrilled to hear you find our platform great for learning new trades and that you decided to subscribe after the free trial. We apologize for the issue with losing streaks after the app update and appreciate your feedback. Our team is working to improve the experience.",
#   'repliedAt': datetime.datetime(2024, 10, 24, 17, 52, 11),
#   'appVersion': '6.0'},
#  {'reviewId': 'f07341be-eb6e-46c0-931c-6701643fa61f',
#   'userName': 'Mohlapu Godfrey',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLUmIuFbAIhY2s8vmYcKu2cGD6yN5rs3hTRV0cJxF4S5ddA=mo',
#   'content': 'Helpful',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 10, 15, 2, 37, 10),
#   'replyContent': 'Thank you for your feedback! We’re glad to hear you found it helpful. If you have any questions or suggestions, feel free to let us know!',
#   'repliedAt': datetime.datetime(2024, 10, 24, 17, 52, 36),
#   'appVersion': '5.3.4'},
#  {'reviewId': '694c2cdd-7742-41c6-9038-6cb067822654',
#   'userName': 'Caple Millings',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXnDmCAORgiSSbS2F6OnEDP69jp3mhTspiRYsrjbEweyBy6SR7k',
#   'content': "I just started to use it I don't know much yet",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 10, 14, 21, 42, 51),
#   'replyContent': "Thank you for your feedback! We're glad you're starting to use the app. If you have any questions or need assistance as you explore, please don’t hesitate to reach out. We’re here to help!\n\n",
#   'repliedAt': datetime.datetime(2024, 10, 24, 17, 52, 55),
#   'appVersion': '5.3.4'},
#  {'reviewId': '689da25e-0a72-417a-9349-1ff63e476d3e',
#   'userName': 'Kendall Walden',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXKlHS7qEoBah14GBvTh5UJTFhRk6JcuUMnZZfqB8bKO-VjQeGu',
#   'content': 'App has been wonderful and they are quick to assist you.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '6.0',
#   'at': datetime.datetime(2024, 10, 14, 21, 8, 3),
#   'replyContent': 'Hey Kendall, the app was under maintenance. It should be up and running now. So sorry for the inconvenience caused by this. You should be able to use the app now. :)',
#   'repliedAt': datetime.datetime(2024, 10, 14, 21, 6, 21),
#   'appVersion': '6.0'},
#  {'reviewId': '20868df0-2199-4384-aa02-d0f1e6926d97',
#   'userName': 'Itai Mashongwa',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXgSDRpSC1yw3A0WKNEyvUuM1qdc8bsDcOTmFW8LsLS1G9FWrA',
#   'content': "It's a very helpful app",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 10, 14, 15, 17, 20),
#   'replyContent': "Thank you for your kind words! We're thrilled to hear that you find the app very helpful. If you have any suggestions or need assistance, feel free to reach out!\n\n",
#   'repliedAt': datetime.datetime(2024, 10, 24, 17, 54),
#   'appVersion': '5.3.4'},
#  {'reviewId': 'ff662baa-2bf0-4007-afb0-77a5d2ff78f7',
#   'userName': 'Azfar Ahmed (Andy)',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUSzMka0d4VqMzLujeqSYf5A6vzog-R2eNCZb_9dUkYzxsW3Bi84Q',
#   'content': 'They teach you step by step. Very easy to learn most difficult things.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 10, 14, 14, 58, 47),
#   'replyContent': "Thank you for your wonderful feedback! We're glad to hear that our step-by-step teaching approach makes it easy for you to learn even the most difficult concepts. If you have any questions or suggestions, please feel free to reach out!",
#   'repliedAt': datetime.datetime(2024, 10, 24, 17, 54, 25),
#   'appVersion': '5.3.4'},
#  {'reviewId': '41ee0765-06d0-43ad-98d5-5058be0bd73a',
#   'userName': 'Abdulaziz Summaila',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocK3fi-ug_iDrX8iEDqrb37KS3CDhs8ql5aaBAXoQtd9WIuv8w=mo',
#   'content': 'Great learning experience',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.0.3',
#   'at': datetime.datetime(2024, 10, 13, 7, 35, 2),
#   'replyContent': "Thank you for your positive feedback! We're delighted to hear that you're having a great learning experience. If you have any questions or need assistance, feel free to reach out!\n\n",
#   'repliedAt': datetime.datetime(2024, 10, 24, 17, 54, 41),
#   'appVersion': '5.0.3'},
#  {'reviewId': '54e41a96-76ad-4c2c-9304-673a15f4c8e0',
#   'userName': 'Anointing K Owusu',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJOpX3vGtyUEPOebCpdvUxKiQl_85uckaJ1tvAtNdaufbNRYg=mo',
#   'content': 'The class was so amazing. I 100% recommend this to all.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 10, 13, 5, 4, 13),
#   'replyContent': "Thank you for your enthusiastic feedback! We're thrilled to hear that you had an amazing class and appreciate your recommendation. If you have any further comments or need assistance, please don’t hesitate to reach out!",
#   'repliedAt': datetime.datetime(2024, 10, 24, 17, 55, 9),
#   'appVersion': '5.3.4'},
#  {'reviewId': '350c9f74-200e-44d8-bd26-32bf9fb1e627',
#   'userName': 'Onyemaobi Emmanuel chinalurumogu',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWup1VaI7UBc3Q7ML5PIQ0MhXuIUa6dSeOGaottaqQljwpYu0sv',
#   'content': 'Very good performance',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 10, 11, 7, 16, 54),
#   'replyContent': "Thank you for your feedback! We're glad to hear that you're pleased with the performance. If you have any suggestions or need assistance, feel free to reach out!\n\n",
#   'repliedAt': datetime.datetime(2024, 10, 24, 17, 55, 31),
#   'appVersion': '5.3.4'},
#  {'reviewId': 'd35b7d2a-bdd4-436f-af5a-73bfa0856f85',
#   'userName': 'Eastwood Herrington',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjV8vDXJ71285qXnjFuZiIi0khcGaaiqc4y7B1ndD7rqnauuZBOb',
#   'content': 'An excellent learning application',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 10, 10, 22, 44, 25),
#   'replyContent': 'Thank you for your kind words! We’re thrilled to hear that you consider our application excellent for learning. If you have any questions or suggestions, feel free to reach out!\n\n',
#   'repliedAt': datetime.datetime(2024, 10, 24, 17, 55, 56),
#   'appVersion': '5.3.4'},
#  {'reviewId': 'c7eaac7f-293e-4781-b2ec-da8d25a88b17',
#   'userName': 'JabULaNE BaLoyi',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUSUvgIWyIFRlFGQ7kon0ZLojpCKezrlBYuI2K6TDFRSnZqyZ5J',
#   'content': 'easy to follow and precise explanations including animation',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 10, 9, 1, 2, 56),
#   'replyContent': "Thank you so much for your lovely feedback! We're thrilled to hear that you find our explanations easy to follow and enjoy the animations. Your support means the world to us! If you have any questions or suggestions, don’t hesitate to reach out. We're here to help!\n\n",
#   'repliedAt': datetime.datetime(2024, 10, 24, 17, 56, 40),
#   'appVersion': '5.3.4'},
#  {'reviewId': 'ba7d2232-cda9-48d8-a32e-79a5918ffd4d',
#   'userName': 'Pierre Patzold',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjV8QXlpGvT2MCI4Evg_BkmFgUTLkFWGI9mn5qobjZgKypBXayXT',
#   'content': "I recently came across Skill Cat and decided to give it a go, I've found the courses well put together! The simulation videos are very Cool, and make learning very informative. It feels like you doing the actual practical, I think Skill Cat are on something good. They new but their aim and vision of how to help people with CPD and accredited learning show they are committed. They gave me a 3 day free trial period and their pricing structure makes one encouraged to to study through them!",
#   'score': 5,
#   'thumbsUpCount': 9,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 10, 7, 17, 40, 45),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '5.3.4'},
#  {'reviewId': 'ca004e03-019c-4d5b-a2a2-9b73b215388b',
#   'userName': 'Henry Murphy',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocK4OAHM88DMAqeE6l9NzjcjycQ3Mnd6ONLQEdrolAvCTpTGUg=mo',
#   'content': 'Well done team,it was a world class experience.Tutorial was great.For me,as a South African,to learn international, WOWW what a great experience.THANX',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 10, 6, 21, 32, 10),
#   'replyContent': "Thank you for your amazing feedback! We're so glad to hear that you had a world-class experience with our tutorials. It’s wonderful to know that our international content resonates with learners like you from South Africa. Your appreciation means a lot to our team! If you have any more thoughts or need assistance, feel free to reach out.",
#   'repliedAt': datetime.datetime(2024, 10, 24, 17, 57, 14),
#   'appVersion': '5.3.4'},
#  {'reviewId': '9ca37820-064c-4e80-90fd-1e71af0427ec',
#   'userName': 'Muhammad Ehtesham',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIifCyqb-ZZtKpjfwzZdtFYrGiTMLVXxdLyTcaj-IjYZ5fPWA=mo',
#   'content': 'Very Good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 10, 6, 4, 5, 6),
#   'replyContent': "Thank you for your feedback! We're glad to hear that you think it's very good. If you have any suggestions or need assistance, feel free to reach out!\n\n",
#   'repliedAt': datetime.datetime(2024, 10, 24, 17, 58, 18),
#   'appVersion': '5.3.4'},
#  {'reviewId': '5c7cca0d-3a94-4180-8d1b-8378041ff9c8',
#   'userName': 'David Davis',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJY-2egRGiyBQ7RLUIfq26-NpQSpkPYAYle_BnIRChfPP6q8A=mo',
#   'content': 'Great App and Study material. I highly recommend this for your 608 Certification. Thank you',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 10, 5, 19, 41, 57),
#   'replyContent': "Thank you for your wonderful feedback! We're delighted to hear that you find our app and study materials great for the 608 Certification. Your recommendation means a lot to us! If you have any questions or need assistance, please feel free to reach out.\n\n",
#   'repliedAt': datetime.datetime(2024, 10, 24, 17, 58, 43),
#   'appVersion': '5.3.4'},
#  {'reviewId': 'cfadef4d-3e34-4a59-8e7e-6cd7d69efc22',
#   'userName': 'Collins Chukwu',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKi9uLeKDdS2TmvUdC0eDfOzxDuKnw8dl0VTITKegrKnSY27A=mo',
#   'content': 'This App is Cool lots of Visual Aids',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 10, 4, 19, 10, 56),
#   'replyContent': "Thank you for your awesome feedback! We're thrilled to hear that you find the app cool and appreciate the visual aids. If you have any suggestions or questions, feel free to reach out. We're here to help!",
#   'repliedAt': datetime.datetime(2024, 10, 24, 17, 59, 5),
#   'appVersion': '5.3.4'},
#  {'reviewId': '72204075-7f1c-4ced-88e0-3391436516e3',
#   'userName': 'alexander morales',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXXzbpvd8xb3rWocLrBrDBGWrgx6LyudR_0CgBLiWCSlIwHZyby',
#   'content': 'I very happy and too many also learn about the EPA 608',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 10, 4, 12, 28, 16),
#   'replyContent': "Thank you for sharing your happiness! We're glad to hear that you're learning a lot about the EPA 608 certification. Your success is important to us, and we're here to support you. If you have any questions or need assistance, feel free to reach out!\n\n",
#   'repliedAt': datetime.datetime(2024, 10, 24, 17, 59, 25),
#   'appVersion': '5.3.4'},
#  {'reviewId': 'a9311fe2-cf2b-43bc-ae71-a7e376347985',
#   'userName': 'Alhaji Alimamy Bangura',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJCB5e107SszwySop8525awte5MfBfJczJrzBHSh_vJsgjhJw=mo',
#   'content': 'Better',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 10, 3, 23, 53),
#   'replyContent': 'Dear User, we are happy to know that you found our app useful. Please help us by spreading the word amongst your friends. If you have any feedback or suggestions, please write to us at info@skillcatapp.com. We would love to hear from you!',
#   'repliedAt': datetime.datetime(2024, 10, 24, 18, 0),
#   'appVersion': '5.3.4'},
#  {'reviewId': 'd5b1c3f0-c5d5-4011-b97b-80e00d21be5b',
#   'userName': 'Nao Siagh',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocI21Hx-A28QgCim4r9WdfOViQOZi96EMEu-HrJLaRQC_b9kHA=mo',
#   'content': 'So interesting',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 10, 3, 19, 4, 38),
#   'replyContent': 'Thanks for taking out time to rate us. It really helps us to keep going and delivering the best :)',
#   'repliedAt': datetime.datetime(2024, 10, 24, 18, 0, 10),
#   'appVersion': '5.3.4'},
#  {'reviewId': '3d471e55-426c-4471-a71d-65eec9358df0',
#   'userName': 'dipak patel',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKWT4qQtYzgYwM_6rwc-8XJ6ZtBG5XwZyVqwri_lAB7a7JAOw=mo',
#   'content': 'Wonderful system....!!! I love... Thanks skill cat....Excellent learning opportunity.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 10, 3, 7, 7, 2),
#   'replyContent': 'Dear User, we are happy to know that you found our app useful. Please help us by spreading the word amongst your friends. If you have any feedback or suggestions, please write to us at info@skillcatapp.com. We would love to hear from you!',
#   'repliedAt': datetime.datetime(2024, 10, 24, 18, 0, 18),
#   'appVersion': '5.3.4'},
#  {'reviewId': 'd5a88101-31dc-4513-8498-9c7155b95173',
#   'userName': 'Anthony Childers',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKFboORmS7FeJfKeQAx0saVB6rEmA8jfH9lThAAK8lyNAEqhw=mo',
#   'content': 'even though I thought I knew everything about common tools and fasteners, I have learned using skillcat. The material is fairly simple, but you do have to commit time and focus to achieve the certificates. Worth subscribing.',
#   'score': 5,
#   'thumbsUpCount': 5,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 10, 3, 3, 50, 37),
#   'replyContent': "Thank you for your thoughtful review! We're delighted to hear that you learned new things about common tools and fasteners through SkillCat. It's great to know that you found the material accessible and valuable. Your commitment to learning is commendable, and we appreciate your recommendation to subscribe.",
#   'repliedAt': datetime.datetime(2024, 10, 24, 18, 0, 49),
#   'appVersion': '5.3.4'},
#  {'reviewId': '842c8a98-89b5-4076-9225-6d3d49bfdd40',
#   'userName': 'Michael',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKccTgIaIvbQJx-Sk7u3dgpsei9gV_ONBMJSnknpW1sHN70rA=mo',
#   'content': 'Am highly interested after going through the Electrical introduction topics. So I wanted to chat with you to continue on the course But onless i Subcribe?',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 10, 2, 11, 16, 54),
#   'replyContent': 'Hey Michael, you can always reach out to us by shooting us an email at info@skillcatapp.com or just give us a call or drop a text at 415-707-8437 and we would love to answer any questions you may have. :)',
#   'repliedAt': datetime.datetime(2024, 10, 2, 13, 16, 5),
#   'appVersion': '5.3.4'},
#  {'reviewId': '576938f0-0a83-4cc8-be96-e499f048bb5e',
#   'userName': 'Auguiste Alexander',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX4HLo_emlvmp1yI1OPhYfU52O_7Rnh1EIwjNm3dLpOdq1TSQ3o',
#   'content': 'it really give me a firm understanding I love it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 9, 28, 22, 54, 9),
#   'replyContent': 'Thank you for your wonderful feedback! We’re thrilled to hear that the app has given you a firm understanding of the material. Your love for our platform means a lot to us! If you have any questions or need further assistance, feel free to reach out.\n\n',
#   'repliedAt': datetime.datetime(2024, 10, 24, 18, 1, 20),
#   'appVersion': '5.3.4'},
#  {'reviewId': '0d314b0f-6fcc-4d3b-8258-a7127ac6396f',
#   'userName': 'Potuan Francis Salayau',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW7lKTeqf2P0qYLLGUPzh1cYmfGVvDGMI7wbv3q5ebfiQVgufo',
#   'content': "I'm intrigued by the way the lessons were taught. Very self-explanatory and intuitive.",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 9, 27, 19, 8, 58),
#   'replyContent': "Thank you for your thoughtful feedback! We're glad to hear that you find the lessons intuitive and self-explanatory. It’s our goal to make learning as engaging and straightforward as possible. If you have any questions or suggestions, please feel free to reach out!\n\n",
#   'repliedAt': datetime.datetime(2024, 10, 24, 18, 1, 38),
#   'appVersion': '5.3.4'},
#  {'reviewId': 'd95d0f70-4e58-4555-858a-762066ee7dee',
#   'userName': 'Melecio C Tenerife Jr',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKiKK6XwOPZ0wvTUdvdjk1Jc0ryg24cHiunMFlDFRmB0CKHmw=mo',
#   'content': 'skillcat is the best online training and exam for EPA',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2024, 9, 27, 9, 15, 13),
#   'replyContent': "Thank you for your fantastic feedback! We're thrilled to hear that you consider SkillCat the best online training and exam for EPA certification. Your support means a lot to us! If you have any questions or need assistance, feel free to reach out.\n\n",
#   'repliedAt': datetime.datetime(2024, 10, 24, 18, 1, 59),
#   'appVersion': None},
#  {'reviewId': 'cecf054b-c0dc-4d84-8d29-fa452af3091b',
#   'userName': 'Isaac Katebe',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVTU-PJC4xGmPFa6ymQw5FMHDXqxYlfyi-7WDvcsJhYWWuOvVRq',
#   'content': 'Excellent',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 9, 26, 22, 55, 23),
#   'replyContent': 'Thank you for your review. Enjoy reading & keep supporting us :)\nIf you have any feedback or suggestion, you could write to us at info@skillcatapp.com. We would love to hear from you!',
#   'repliedAt': datetime.datetime(2024, 10, 24, 18, 2, 18),
#   'appVersion': '5.3.4'},
#  {'reviewId': '9f35f3cc-29ca-4118-a9c6-3c41d8cb8bb4',
#   'userName': 'Matthew Betts',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVFiouVmumtm1nnK2yw7gpBmoTfzSJDBT2F_7J2J4sVpLNKReEi',
#   'content': 'amazing app',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 9, 26, 11, 11, 36),
#   'replyContent': 'Dear friend, we are really glad that you like our product. Your support and voice are very important to us.',
#   'repliedAt': datetime.datetime(2024, 10, 24, 18, 2, 33),
#   'appVersion': '5.3.4'},
#  {'reviewId': 'c384c196-2b7b-42ff-86f3-0ea36ba30ea4',
#   'userName': 'Thabiso Lentswane',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKfNPZFIuf5ugefC2sxYJHFW5ZQzHT1tlzXhZI6gf-vVPFbHg=mo',
#   'content': 'Well appreciated knowledge gained. Thank you very much.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 9, 24, 18, 49, 23),
#   'replyContent': "\nHello,\n\nThank you for your kind words! We're so glad to hear that you gained valuable knowledge from our platform. Your appreciation means a lot to us. If you have any questions or need further assistance, please feel free to reach out.",
#   'repliedAt': datetime.datetime(2024, 10, 24, 18, 3, 2),
#   'appVersion': '5.3.4'},
#  {'reviewId': 'fab7aca0-de27-4785-ad60-742ff92ec635',
#   'userName': 'Michael Younker',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLYiltyAwr8qBhbAqDBDQr4TbKb6AAJWaGJ0YpvnJI0XCDdIA=mo',
#   'content': 'Great program! Best way to get your certifications. Definitely a life changer. Highly recommend skillcat for EPA 608 certifications',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 9, 23, 4, 37, 17),
#   'replyContent': "Thank you for your amazing feedback! We're thrilled to hear that you find our program a great way to get your certifications and that it has been a life changer for you. Your high recommendation for SkillCat and the EPA 608 certification means a lot to us! If you have any questions or need assistance, feel free to reach out.\n\n",
#   'repliedAt': datetime.datetime(2024, 10, 24, 18, 3, 28),
#   'appVersion': '5.3.4'},
#  {'reviewId': '5add2fb6-d3b5-494b-b879-ac999e7d351e',
#   'userName': 'Aubrey Ngcobo',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIrDWm4D9jiXkpk-RlFY8hqKZi3o6Iy_FHCqxdDtJdphDXzJA=mo',
#   'content': "This is no joke this app does what it say it does I've got my certificate and it got verified its no scam but hope to buy it in future to support the company.",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 9, 20, 3, 43, 52),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '5.3.4'},
#  {'reviewId': 'a09fdca7-4433-4295-b588-c34d441f0b73',
#   'userName': 'Saheed Salami',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJa2M9Ug2-VTqV5zsYqjtr8X4BQcMcXYW5aLQqvLHf10kC_vw=mo',
#   'content': 'This app is so magnificent. I enjoy every bit of it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 9, 20, 1, 19),
#   'replyContent': "Thank you for your wonderful feedback! We're delighted to hear that you find the app magnificent and enjoy using it. Your enthusiasm means so much to us! If you have any suggestions or questions, please feel free to reach out.",
#   'repliedAt': datetime.datetime(2024, 10, 24, 18, 3, 48),
#   'appVersion': '5.3.4'},
#  {'reviewId': '82f4c4fd-726a-4875-8bb4-e5399eaea851',
#   'userName': 'Diomedes Ovalle',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLhMrSg7W7Spnpp5rtY76wKbBP3xQQOxLcgss9uAytGEKZFfg=mo',
#   'content': 'best app to do your EPA 608!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 9, 17, 3, 28, 11),
#   'replyContent': 'We are pleased that you enjoyed the app. If there is anything we can do for you, just let us know at info@skillcatapp.com!\nHave a wonderful day!',
#   'repliedAt': datetime.datetime(2024, 10, 24, 18, 3, 58),
#   'appVersion': '5.3.4'},
#  {'reviewId': '5129eb69-6267-457b-9ca7-b60ce34a81bc',
#   'userName': 'Gibson Phiri',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLpP4qMpVL0dr2N6h6BGyLuq1xTn9w9EPrl48NRW34Z6hwLGg=mo',
#   'content': 'Good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.0.3',
#   'at': datetime.datetime(2024, 9, 16, 17, 16, 38),
#   'replyContent': 'Thanks a lot for your rating :)',
#   'repliedAt': datetime.datetime(2024, 10, 24, 18, 4, 10),
#   'appVersion': '5.0.3'},
#  {'reviewId': '490a3215-f796-4298-b854-2befb1d2773a',
#   'userName': 'D.J. Sexton I',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWWa49vPz1tzuf0UlDd7_G-873TsRiZhrXgWVn9XAFr1TkVIO5S',
#   'content': 'For busy adults in this modern society who are looking to advance their education in certain trades in order to increase their salaries, then enroll with SkillCat ASAP!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 9, 16, 14, 7, 19),
#   'replyContent': "Thank you for your insightful recommendation! We're glad to hear that you see the value of SkillCat for busy adults looking to advance their education and increase their salaries. Your enthusiasm for our platform is much appreciated! If you have any questions or need assistance, feel free to reach out.\n\n",
#   'repliedAt': datetime.datetime(2024, 10, 24, 18, 4, 31),
#   'appVersion': '5.3.4'},
#  {'reviewId': '213ada17-e935-4869-8ec5-e49e4b9ca862',
#   'userName': 'M R (Miguels Canvas)',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUzXf20e2ylgTv1gbgGg1xdWi9sJHKDKVC3ZuJnaladKQGjXey4',
#   'content': 'awesome app and website for studying and testing trade certifications',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 9, 14, 6, 38, 44),
#   'replyContent': "Thank you for your fantastic feedback! We're thrilled to hear that you find our app and website awesome for studying and testing trade certifications. Your support means a lot to us! If you have any questions or need assistance, please feel free to reach out.\n\n",
#   'repliedAt': datetime.datetime(2024, 10, 24, 18, 4, 49),
#   'appVersion': '5.3.4'},
#  {'reviewId': 'e079c085-360d-4afe-a6e0-3774541b86c1',
#   'userName': 'Jimmy Yi',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUQGlAr_ctCKgeWDJsoQab5ZnBj9pIoXtSzN6K41Q95DtyNG_U',
#   'content': 'This application is truly beneficial and has been of great assistance to me. It is remarkably user-friendly and provides a wealth of valuable information. I express my sincere gratitude to SkillCat for developing such a remarkable tool.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 9, 13, 4, 28, 25),
#   'replyContent': "Thank you for your heartfelt feedback! We're so glad to hear that you find our application beneficial and user-friendly. It's wonderful to know that it has been a great assistance to you. Your gratitude means a lot to us, and we're committed to providing valuable information. If you have any questions or suggestions, please feel free to reach out!",
#   'repliedAt': datetime.datetime(2024, 10, 24, 18, 5, 25),
#   'appVersion': '5.3.4'},
#  {'reviewId': '1e49b5e4-5590-44c7-b880-49a2f8dfdaf5',
#   'userName': 'Tebogo Tshwaro',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW39XS49AQ6_13RwgUEvNxBrHBl1zlDdeNmbUTapY8lAeGe8bp7',
#   'content': 'This is a great app and I like it because you can do online course for free.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 9, 12, 18, 46, 32),
#   'replyContent': 'Thank you so much for your review!',
#   'repliedAt': datetime.datetime(2024, 10, 24, 18, 5, 48),
#   'appVersion': '5.3.4'},
#  {'reviewId': '1a796c77-32d6-4852-80b6-04888c94d7d2',
#   'userName': 'Jim Flynn',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKieveSE5D7XKDGitye8U6Up7i2ra3DvkdPIqnZyxIsCBQXCA=mo',
#   'content': 'love it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 9, 10, 7, 6, 6),
#   'replyContent': 'Thanks for your love. If you have any questions, please contact us at info@skillcatapp.com.',
#   'repliedAt': datetime.datetime(2024, 10, 24, 18, 7, 31),
#   'appVersion': '5.3.4'},
#  {'reviewId': '653d7ca7-3626-4221-a14c-089cbd7f647a',
#   'userName': 'R.S. Sommers',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKtvREg4ZPSy65UsuCnR2TbaBmW5ZQWXaXUWOdJkbwA4dveOQ=mo',
#   'content': 'yay...well planned and executed',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 9, 9, 4, 35, 57),
#   'replyContent': 'Thank you very much for your 5-star review!!!',
#   'repliedAt': datetime.datetime(2024, 10, 24, 18, 7, 37),
#   'appVersion': '5.3.4'},
#  {'reviewId': '86ca9d6f-ee82-40b3-ad3e-e461800f6a2b',
#   'userName': 'John Pavel',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIxrgbCdRu1XssJBYVaaA6E0wwGOqILx07p1f9ejgPNVWIzxRCf=mo',
#   'content': 'best app',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 9, 8, 2, 19, 42),
#   'replyContent': 'Thank you very much. Keep using our app :)',
#   'repliedAt': datetime.datetime(2024, 10, 24, 18, 7, 44),
#   'appVersion': '5.3.4'},
#  {'reviewId': '3b4554d9-dc4c-4100-9da9-b9b5389d7794',
#   'userName': 'Juan Herrera',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUOhqvITwKRVWc5erktRu149Skn9B9COWyI6dEprynzS-iro9wY',
#   'content': 'Nice',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 9, 7, 11, 3, 49),
#   'replyContent': 'Dear User, we are happy to know that you found our app useful. Please help us by spreading the word amongst your friends. If you have any feedback or suggestions, please write to us at info@skillcatapp.com. We would love to hear from you!',
#   'repliedAt': datetime.datetime(2024, 10, 24, 18, 7, 59),
#   'appVersion': '5.3.4'},
#  {'reviewId': '461940b5-5f12-4032-bb62-3c2d78ed103c',
#   'userName': 'Fredy Tapia',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXihcNpI6mPIYOchtDT5xwuQEfpVlYh1GswzW4Tp3E7sGP2wwpy',
#   'content': 'Great resource for HVAC techs',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 9, 7, 0, 24, 13),
#   'replyContent': 'We are pleased that you enjoyed the app. If there is anything we can do for you, just let us know at info@skillcatapp.com!\nHave a wonderful day!',
#   'repliedAt': datetime.datetime(2024, 10, 24, 18, 8, 9),
#   'appVersion': '5.3.4'},
#  {'reviewId': 'a7211f41-a83b-4618-b9bd-2962b01883f3',
#   'userName': 'Avril Martin',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUBDLdX2dO4KBwiD7PX3llbtT1JyEFjRInFfdxlcgmMZD0UZyMW',
#   'content': "I love this app, I'm busy with my Plumbing certificate and it's going very well. Thank you SkillCat!",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 9, 6, 22, 49, 2),
#   'replyContent': "Thank you for your wonderful feedback! We're delighted to hear that you love the app and that your Plumbing certificate is going well. Your success is important to us, and we're here to support you on your journey. If you have any questions or need assistance, please feel free to reach out!",
#   'repliedAt': datetime.datetime(2024, 10, 24, 18, 8, 49),
#   'appVersion': '5.3.4'},
#  {'reviewId': '3f8bb684-4058-4e42-b215-a36555442e8d',
#   'userName': 'Andrew Cabanas',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJl9nZajySyiHW89of54GtMWhzl6buGN8ISiwk0FC9AqaJ75Q=mo',
#   'content': 'gotta wait for the test to be checked for the proctor stuff.. took me about 7 days from start to finish with no prior training. I love it and plan to get more certifications with this program. Thank You SkillCat!!',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '5.3.4',
#   'at': datetime.datetime(2024, 9, 5, 19, 8, 33),
# ...
#   'appVersion': '1.3.0'},
#  {'reviewId': '377a1ec4-b1d3-473f-b446-9a9bfd01d59f',
#   'userName': 'n2eik',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocI7ww2gxdzz9iJibjMObKCrHNRTSCOGTRPVn4Bts9REnONnsw=mo',
#   'content': 'Worked great. Highly recommended.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.3.0',
#   'at': datetime.datetime(2022, 1, 21, 5, 56, 9),
#   'replyContent': 'Hi,\nThank you so much for your kind words!\nWe appreciate you taking the time to share your experience with us. Please let us know if you have any suggestions or feedback to improve your experience. You can always reach out to us at support@skillcatapp.com.\nThank you!',
#   'repliedAt': datetime.datetime(2022, 7, 9, 22, 33, 29),
#   'appVersion': '1.3.0'},
#  {'reviewId': 'e85f0f24-93c3-4a1d-abaa-fa17d58eb249',
#   'userName': 'bryanh194',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocI0c96plIkkI6MKbVvbqtLr-hZGr1SogrDWt_e-jfVftlpDCQ=mo',
#   'content': 'Attempted to sign up, but unable to complete registration... Stuck on "loading"',
#   'score': 2,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.3.0',
#   'at': datetime.datetime(2022, 1, 19, 1, 34, 12),
#   'replyContent': 'Hi! We are glad to inform you that the issue with the registration has been sorted out. You should be able to register seamlessly now. We request you to please try and sign up on the app once again. We sincerely apologize for all the inconvenience. If you have any other trouble, please contact us at info@skillcatapp.com',
#   'repliedAt': datetime.datetime(2022, 1, 23, 3, 49, 59),
#   'appVersion': '1.3.0'},
#  {'reviewId': '744987c3-88f6-4884-bc83-27db907e67d8',
#   'userName': 'Silva Jay',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVGRmncTt_5wT_d79DrA8LV_Qu0rVsycSj6eoMFxV1Sy20RcHwDjg',
#   'content': 'was working great then about day 3 it stopped registering the modules that I completed.',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.2.3',
#   'at': datetime.datetime(2022, 1, 12, 21, 29, 37),
#   'replyContent': 'Hi, Silva!\nWe are very sorry you are facing this issue.\nPlease email us the issue in detail to support@skillcatapp.com, and we will help you the best we can..\nThank you!',
#   'repliedAt': datetime.datetime(2022, 7, 9, 22, 36, 29),
#   'appVersion': '1.2.3'},
#  {'reviewId': 'caf3ad6b-d62c-4b29-8d50-e731ce2e454b',
#   'userName': 'Don Lane',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUjIZwGyE-6O2L9AOmFbO8iR29XsTcLnUGAa5OvBNPoUtKRxAQN',
#   'content': 'when i took my tesr for 608 universal i used a cromebook that didnot work well with skillcat so i used my cell phone an it work great i highly reccomend them. Dom Lane',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.2.3',
#   'at': datetime.datetime(2022, 1, 11, 0, 0, 33),
#   'replyContent': 'Hi Don! Thanks a lot for your positive review. With every new app version, we are introducing new features and improving existing ones. Your feedback will only help us improve further. Please write to us at info@skillcatapp.com, if you have any feedback or suggestions!',
#   'repliedAt': datetime.datetime(2022, 1, 11, 3, 23, 58),
#   'appVersion': '1.2.3'},
#  {'reviewId': '444da386-2489-4d4a-ab42-9a21f92bfcba',
#   'userName': 'Hey there',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLjBfqaERGOpitrdpd_MGO9ti7WpfQBlxwMFRPjIhlSA9o_Kw=mo',
#   'content': "Excellent app to launch into HVAC. I have been working in the HVAC field for six months and Skillcat improved much of my understanding of what I was working on. It may have a few errors during the courses, however, it was nothing big. The courses are set up in a way a person can learn the basics to be confident enough on the first day of the job where ever a person may work! I'm now EPA UNIVERSAL Certified thanks to Skillcat!",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2021, 12, 27, 23, 7, 24),
#   'replyContent': 'Hi! Thanks a lot for your positive review. With every new app version, we are introducing new features and improving existing ones. Your feedback will only help us improve further. Please write to us at info@skillcatapp.com, if you have any feedback or suggestions!',
#   'repliedAt': datetime.datetime(2021, 12, 29, 15, 59, 30),
#   'appVersion': None},
#  {'reviewId': '568f3b77-9dcc-4a1d-93ea-1ec3e262dbe7',
#   'userName': 'David Junior',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKXOV-g1AbYuTKH2U5cSX67xq6kkTyNmgFopmCZs06ZNGrT1Q=mo',
#   'content': "I cant do any courses as I have auto rotate on and it tells me to rotate my phone sideways but won't let me rotate it in the app for some reason. Seems good but can't tell as I can't even get through the first part of training.",
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.2.3',
#   'at': datetime.datetime(2021, 12, 24, 2, 50, 11),
#   'replyContent': "We are really sorry for the trouble and we appreciate you bringing this issue to our attention. To access the course materials, you need to switch your phone from portrait mode to landscape by turning on auto-rotate.\nYou can always send us your concerns at info@skillcatapp.com and we'll help you sort any issues!\n",
#   'repliedAt': datetime.datetime(2021, 12, 29, 14, 37, 8),
#   'appVersion': '1.2.3'},
#  {'reviewId': '6ac72428-e1b0-4c96-90fa-6002525d8b39',
#   'userName': 'trevor constans',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJC3uuP6XSJtS-X4aly4XHfpdDz7LNd5e_gXOacp1-by2d_uQ=mo',
#   'content': "Love this app extremely useful. Only problem making it not 5 stars is any training test I am submitting is saying invalid course ID so my tests won't submit. But the knowledge has been amazing and is easy to follow many useful tips and works from knowing nothing to being able to answer every question they throw at you. Would recommend to anyone wanting to join HVAC field.",
#   'score': 4,
#   'thumbsUpCount': 6,
#   'reviewCreatedVersion': '1.2.3',
#   'at': datetime.datetime(2021, 12, 19, 1, 59, 33),
#   'replyContent': "Hi Trevor, we're so sorry to hear you were having problems. The issue has now been resolved and we hope you have a smoother learning experience! Let us know at info@skillcatapp.com if you face any other issues. Thanks!\n\n",
#   'repliedAt': datetime.datetime(2021, 12, 23, 17, 57, 50),
#   'appVersion': '1.2.3'},
#  {'reviewId': '593fba7b-a584-49e1-9522-b7c3942cb0f7',
#   'userName': 'Terry Linton',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLY0DV4T47nFG2zPl82N8TQz1WpKZ1iYdk8ooLH-fiblSclkA=mo',
#   'content': "It won't let me finish a test, it keeps saying some kinda error happened. Also there is no way to get in contact with the app to let them know",
#   'score': 1,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '1.2.3',
#   'at': datetime.datetime(2021, 12, 18, 5, 29, 25),
#   'replyContent': "Hi Terry,\nWe're so sorry to hear you were having problems. The issue has now been resolved and we hope you have a smoother learning experience! Let us know at info@skillcatapp.com if you face any other issues.\nThanks!",
#   'repliedAt': datetime.datetime(2021, 12, 23, 17, 57, 17),
#   'appVersion': '1.2.3'},
#  {'reviewId': 'afd52963-dfac-4fb9-b7da-b53af3b3bb28',
#   'userName': 'John Sewell',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLKxgBNXqAvIolM2FuG3UZ2gmpJ6FDKtSFa-j3_eaJ--EYD8A=mo',
#   'content': 'So far so good! Some issues but I am excited for the future if this app.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.2.3',
#   'at': datetime.datetime(2021, 12, 14, 6, 7, 5),
#   'replyContent': 'Hi John, thank you so much for sharing your valuable & useful feedback. If you have other feedback or suggestions, please write to us at info@skillcatapp.com. We would love to hear from you!\n',
#   'repliedAt': datetime.datetime(2021, 12, 20, 18, 1, 32),
#   'appVersion': '1.2.3'},
#  {'reviewId': '27ee9121-e3d9-49b1-86c2-9b4387673f49',
#   'userName': 'Dory Tovstiuk',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWl7AHUnCXTwrq8usOuPDn8TA-pN-ggqtd0jq04EqgAacFxxsq6',
#   'content': 'Best App Ever',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.2.3',
#   'at': datetime.datetime(2021, 12, 13, 4, 10, 34),
#   'replyContent': 'Hi Dory! Thanks for your review! Please recommend our app to your friends, and don’t hesitate to shoot us a note at info@skillcatapp.com if you have any concerns or suggestions!',
#   'repliedAt': datetime.datetime(2021, 12, 13, 18, 29, 9),
#   'appVersion': '1.2.3'},
#  {'reviewId': '169de444-f665-4b38-9350-3ccabb298d5c',
#   'userName': 'Andriy Tovstiuk',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW_u7R6lQiTh3PV_jnh2ztio5TKqAo0nQ1nsIi4_OKxAb9tksqIgg',
#   'content': 'Incredible app.... Courses are awesome.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.2.3',
#   'at': datetime.datetime(2021, 12, 12, 5, 9, 36),
#   'replyContent': 'Hi Andriy, thank you so much for sharing your valuable & useful feedback. If you have other feedback or suggestions, please write to us at info@skillcatapp.com. We would love to hear from you!',
#   'repliedAt': datetime.datetime(2021, 12, 13, 18, 28, 24),
#   'appVersion': '1.2.3'},
#  {'reviewId': '0a1a55e6-fe2d-4cdf-964f-dcfe826fc416',
#   'userName': 'Jose Taf',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJcIbQpOiLFFzSuVJBwJeHWXDiors2-iEwxsOqycgX-m4vlzw=mo',
#   'content': 'Wonderful app and website. Epa 608 free and NATE prep free. Thanks guys of SkillCat',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '1.2.3',
#   'at': datetime.datetime(2021, 12, 9, 5, 54, 27),
#   'replyContent': 'Hi Jose, thank you very much for sharing your valuable & useful feedback! If you have other feedback or suggestions, please write to us at info@skillcatapp.com. We would love to hear from you!',
#   'repliedAt': datetime.datetime(2021, 12, 13, 18, 21, 1),
#   'appVersion': '1.2.3'},
#  {'reviewId': '5f5f247f-ff14-4b32-8557-a945ce4c81d5',
#   'userName': 'shashank tripathi',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXKJjNClIWrYfiwpjCL2vKDcN26ZQvoeHJQbLPA-dCKeshdlr-z',
#   'content': 'Nice keep it up ☺️',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.2.2',
#   'at': datetime.datetime(2021, 12, 7, 16, 39, 5),
#   'replyContent': 'Hi, Shashank! Thanks a lot for your positive review. With every new app version we are introducing new features and improving existing ones. Your feedback will only help us improve further. Please write to us at info@skillcatapp.com, if you have any feedback or suggestions!',
#   'repliedAt': datetime.datetime(2021, 12, 13, 18, 20, 10),
#   'appVersion': '1.2.2'},
#  {'reviewId': '65467b82-f194-46d7-abdc-58aae65a13a0',
#   'userName': 'Pritam',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVKh17v-W_-UoCgKRUeOgIsyC0ufpkTYbc0Ecc3HJjWdY-gp36f',
#   'content': 'Really incredible e-learning platform!!!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.2.2',
#   'at': datetime.datetime(2021, 12, 6, 20, 55, 51),
#   'replyContent': 'Hi Pritam! We are so happy to know that you found our app useful. Please help us by spreading the word amongst your friends. If you have any feedback or suggestions, please write to us at info@skillcatapp.com. We would love to hear from you!',
#   'repliedAt': datetime.datetime(2021, 12, 13, 18, 18, 10),
#   'appVersion': '1.2.2'},
#  {'reviewId': '2dfecc84-39a4-4a3a-8d83-fa882d79cbf1',
#   'userName': 'Randolph Roach',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKtrH7KWOVdb3d6saeZDoeEcdHBjj9N_0msVoFKLVJhfx2trQ=mo',
#   'content': "Excellent experience so far. I have made my way through a good portion of the lessons, and so far it has been really easy to navigate and breaks up lessons into practical application videos, repetitive examples to show new skills, and quizzes throughout to make sure you understand what you learned. Being able to do the lessons on my phone is a big deal too, I'm self employed, wich means my schedule is unpredictable, but I can work on this anytime, anywhere. Just perfect.",
#   'score': 5,
#   'thumbsUpCount': 27,
#   'reviewCreatedVersion': '1.0',
#   'at': datetime.datetime(2021, 12, 5, 5, 51, 39),
#   'replyContent': 'Hi, Randolph! Thanks a lot for your positive review. With every new app version we are introducing new features and improving existing ones. Your feedback will only help us improve further!',
#   'repliedAt': datetime.datetime(2021, 12, 13, 18, 17, 20),
#   'appVersion': '1.0'},
#  {'reviewId': '6809bc56-fc35-495c-a826-b74e71ff61d4',
#   'userName': 'Sam Hile',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWrDiMWG69Ez81BMSJsfmFYaYhf7esu0X-RbtdUfCQOt1FInPyf3A',
#   'content': 'Great app - would definitely recommend for anyone in HVAC!',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '1.2.2',
#   'at': datetime.datetime(2021, 12, 5, 5, 13, 6),
#   'replyContent': 'Hi Sam! Thanks for your review! Please recommend our app to your friends, and don’t hesitate to shoot us a note at info@skillcatapp.com if you have any questions or concerns!',
#   'repliedAt': datetime.datetime(2021, 12, 13, 18, 16, 22),
#   'appVersion': '1.2.2'},
#  {'reviewId': '62aec908-3e5d-43fa-9e33-7790123096e0',
#   'userName': 'Matthew',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIOFUP6klW06k6VjM8kYOcnjMd_cIjaSAepn5zmjvKcTqUHlA=mo',
#   'content': 'Great app, really enjoy using it!',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '1.2.2',
#   'at': datetime.datetime(2021, 12, 5, 2, 57, 55),
#   'replyContent': 'Thanks for your review! Please recommend our app to your friends, and don’t hesitate to shoot us a note at info@skillcatapp.com if you have any questions.',
#   'repliedAt': datetime.datetime(2021, 12, 13, 18, 15, 47),
#   'appVersion': '1.2.2'},
#  {'reviewId': '67f4f83a-bcbe-4aba-ace4-c30eb9cbcc92',
#   'userName': 'Mytri Naik',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXigoicZOsfCd77sYM3n7Mm6Mv1Xdwg2B9h7SeKl6az80-MuTWgDw',
#   'content': 'Wonderful experience. Was not buggy at all, very seamless experience.',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '1.2.2',
#   'at': datetime.datetime(2021, 12, 3, 1, 38, 21),
#   'replyContent': 'Hi, Mytri! Thanks a lot for your positive review. With every new app version we are introducing new features and improving existing ones. Your feedback will only help us improve further!',
#   'repliedAt': datetime.datetime(2021, 12, 4, 18, 27, 7),
#   'appVersion': '1.2.2'},
#  {'reviewId': '0a9142c9-c5e8-4fd1-bc85-16fa39d8b9ba',
#   'userName': 'Jai Desai',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWMN5BsQXQrRU_cMsOXrA1X0XhZXbV0fWyIH7fbNFW5sqJwJ5HD5w',
#   'content': 'Thank you SkillCat for releasing this awesome app internationally! Love the interface and of course all the free courses you guys offer.',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2021, 12, 2, 13, 54, 15),
#   'replyContent': 'Hi, Jai! Thanks a lot for your positive review. With every new app version we are introducing new features and improving existing ones. Your feedback will only help us improve further!',
#   'repliedAt': datetime.datetime(2021, 12, 4, 18, 27, 32),
#   'appVersion': None},
#  {'reviewId': 'd60a01af-3bf6-43be-be2b-720722e2d916',
#   'userName': 'Sid',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU-RjQ3nzCiIxUYVDniVD4O6ECfx3KN4u4ogCqDlnb0FQdlf-W1Yg',
#   'content': 'Awesome App. Love the courses and simulations. Especially the simulations, they can be so immersive and detailed.',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '1.2.1',
#   'at': datetime.datetime(2021, 12, 2, 13, 12, 19),
#   'replyContent': 'Hi, Sid! Thanks a lot for your positive review. With every new app version we are introducing new features and improving existing ones. Your feedback will only help us improve further!',
#   'repliedAt': datetime.datetime(2021, 12, 4, 18, 27, 54),
#   'appVersion': '1.2.1'},
#  ...]

# %%
dataframe = pd.json_normalize(skill_cat_app)

# %%
dataframe.head()
# Out:
#                                reviewId         userName  \
# 0  d0379e6a-cb80-4e70-91ba-fe25952f82fb    Andrew Coffey
# 1  116d668e-b0c9-4c01-8196-8eaabe29b906    Salami Saheed
# 2  8a2028f3-916c-47bf-a568-267210cae2aa  Bill Fitzgerald
# 3  7f0a3992-49cd-4a40-8345-4259d9ecaf29       dj Ovamarz
# 4  1accd0cc-6efe-49d9-bfdc-a18eea12b3b6   Nicolas Bowman
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0                                           not free      1              0
# 1  I can't imagine how much I have learned about ...      5              0
# 2  awesome app! got 608 cert and other training o...      5              0
# 3                                               uhhh      5              0
# 4  Now that the update is allowing me to get on s...      5              0
#
#   reviewCreatedVersion                  at  \
# 0                 None 2024-11-09 04:07:53
# 1                5.3.4 2024-11-07 19:06:00
# 2                6.0.1 2024-11-07 08:59:23
# 3                6.0.1 2024-11-07 00:48:55
# 4                6.0.1 2024-11-06 04:50:27
#
#                                         replyContent           repliedAt  \
# 0                                               None                 NaT
# 1                                               None                 NaT
# 2                                               None                 NaT
# 3                                               None                 NaT
# 4  Thanks for your review and we appreciate you t... 2024-11-06 02:48:00
#
#   appVersion
# 0       None
# 1      5.3.4
# 2      6.0.1
# 3      6.0.1
# 4      6.0.1

# %%
dataframe['score'].mean()
# Out:
# 4.702064896755163

# %%
dataframe['reviewCreatedVersion'].value_counts()
# Out:
# reviewCreatedVersion
# 5.0.3    72
# 2.2.5    69
# 2.2.3    60
# 5.3.4    50
# 2.3      48
# 2.1.3    48
# 1.8      41
# 1.5.1    39
# 1.5      37
# 2.2.2    37
# 1.7      36
# 1.9.1    28
# 2.0.1    28
# 5.2.1    24
# 4.8      22
# 1.6.2    21
# 5.3.2    18
# 5.1.1    18
# 6.0.1    18
# 1.6      14
# 2.4      14
# 1.9.3    13
# 4.8.1    13
# 5.0.2    13
# 5.1      13
# 1.4      12
# 1.3.3    11
# 1.3.2    10
# 1.3.0    10
# 1.2.2    10
# 2.1.2     9
# 2.1.1     9
# 1.2.3     9
# 5.3.3     8
# 1.9.2     8
# 2.0       8
# 5.3.1     8
# 1.6.1     7
# 1.4.2     7
# 4.8.2     6
# 6.0       4
# 1.2.0     4
# 2.1       3
# 1.2.1     3
# 5.3       2
# 1.4.5     1
# 5.0.1     1
# 1.0       1
# 1.0.5     1
# 0.1.8     1
# Name: count, dtype: int64

# %% [markdown]
# ### We want to run a deep learning pre trained model on top these comments to get a sentiment analysis so that we can find if they are positive or negative

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

sentiment_analysis = pipeline("text-classification", model="siebert/sentiment-roberta-large-english")
# Out:
# c:\Users\ankus\AppData\Local\Programs\Python\Python312\Lib\site-packages\threadpoolctl.py:1214: RuntimeWarning:
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#   warnings.warn(msg, RuntimeWarning)
# WARNING:tensorflow:From c:\Users\ankus\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# pytorch_model.bin:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/256 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]

# %%
print(sentiment_analysis("I love SkillCat!"))
# Out:
# [{'label': 'POSITIVE', 'score': 0.9988139867782593}]
